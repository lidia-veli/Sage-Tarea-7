# %% [markdown]
# 1. Dibuja la gráfica de $y=sin(\pi x - \pi)$ para $-1 \leq x \leq 1$ usando una línea roja gruesa.

# %%
x = var('x')
plot( sin(pi*x-pi) , (x, -1, 1), color='red' )
# Out:
# Graphics object consisting of 1 graphics primitive

# %% [markdown]
# 2. Dibuja la gráfica de $cos(\pi x - \pi)$ en el mismo intervalo, usando una línea gruesa azul.

# %%
plot( cos(pi*x-pi) , (x, -1, 1), color='blue' )
# Out:
# Graphics object consisting of 1 graphics primitive

# %% [markdown]
# 3. Dibuja las dos curvas anteriores sobre el mismo sistema de ejes.

# %%
lista3 = []
lista3.append( plot( sin(pi*x-pi) , (x, -1, 1), color='red' ) )
lista3.append( plot( cos(pi*x-pi) , (x, -1, 1), color='blue' ) )
sum(lista3)
# Out:
# Graphics object consisting of 2 graphics primitives

# %% [markdown]
# 4. Dibuja la gráfica de $y=\frac{1}{x}$ para $-1 \leq x \leq 1$ ajustando el rango, de tal manera que sólo $-10 \leq y \leq 10$.

# %%
plot(1/x, x, xmin=-1, xmax=1, ymin=-10, ymax=10)
# Out:
# Graphics object consisting of 1 graphics primitive

# %% [markdown]
# 6. Dibuja $x = cos (3t)$ , $y = cos (t + cos (3t))$.

# %%
t = var('t')
parametric_plot( (cos(3*t) , cos(t+cos(3*t))) , (t,0,2*pi))
# Out:
# Graphics object consisting of 1 graphics primitive

# %% [markdown]
# 7. Dibuja la superficie dada por la ecuación $z = x^{2}-y^{2}$ en el recinto $[-5, 5]\times[-5, 5]$.

# %%
y = var('y')
plot3d(x**2 - y**2, (x,-5,5), (y,-5,5))
# Out:
# Graphics3d Object

# %% [markdown]
# 8. Dibuja la superficie dada implícitamente por la ecuación $x^{2}+y^{2}-z^{2}=0$ en el recinto $[-5, 5]\times[-5, 5]\times[-5, 5]$

# %%
# z = sqrt(x^2+y^2)
plot3d(sqrt(x**2+y**2), (x,-5,5), (y,-5,5), zmin=-5,zmax=5)
# Out:
# Graphics3d Object

# %% [markdown]
# 9. Sobre el mismo sistema de ejes que la superficie anterior, dibuja el plano $2x + y + z = 1$ de color rojo.

# %%
# z = 1-2x-y
plot3d(1-2*x-y, (x,-5,5), (y,-5,5), zmin=-5,zmax=5, color='red')
# Out:
# Graphics3d Object

# %% [markdown]
# 10. Lo mismo, pero ahora con los planos $x-z + 3 = 0$ de color verde y $0.5x + 0.5y + z = 1.4$ de color púrpura.

# %%
lista10 = []
lista10.append( plot3d(x+3, (x,-5,5), (y,-5,5), zmin=-5,zmax=5 , color='green'))
lista10.append( plot3d(1.4-0.5*x-0.5*y, (x,-5,5), (y,-5,5), zmin=-5,zmax=5 , color='purple'))
sum(lista10)
# Out:
# Graphics3d Object
